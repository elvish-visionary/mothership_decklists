# %%
from utils import df_to_markdown
import pandas as pd

# %%
df = pd.read_csv('/home/ben/mothership_decklists/processed_results/raw_legacy_challenge_preban_results.csv')
df_post = pd.read_csv('/home/ben/mothership_decklists/processed_results/raw_legacy_challenge_postban_results.csv')

# %%
df['Date'] = pd.to_datetime(df['Date'])
df_post['Date'] = pd.to_datetime(df_post['Date'])

# %%
preban = df['Deck'].value_counts() / df['Deck'].value_counts().sum()

postban = df_post['Deck'].value_counts() / df_post['Deck'].value_counts().sum()
postban
# Out:
# Miracles             0.097222
# Grixis Control       0.074074
# Grixis Delver        0.064815
# Sneak and Show       0.060185
# ANT                  0.052083
# Death and Taxes      0.046296
# 12 Post Eldrazi      0.045139
# Death's Shadow       0.039352
# Lands                0.032407
# Turbo Depths         0.031250
# RUG Delver           0.028935
# Eldrazi Stompy       0.027778
# BR Reanimator        0.027778
# Mana Dredge          0.025463
# Elves                0.023148
# TES                  0.021991
# 4c Loam              0.021991
# UR Delver            0.020833
# Moon Stompy          0.017361
# UWx Stoneblade       0.017361
# Burn                 0.016204
# Delver Blade         0.015046
# OmniTell             0.015046
# Infect               0.015046
# Other (Rogue)        0.015046
# Czech Pile           0.012731
# Other (Blue)         0.012731
# Steel Stompy         0.011574
# Merfolk              0.010417
# Maverick             0.010417
# Manaless Dredge      0.009259
# Esper Blade          0.009259
# BUG Control          0.008102
# Other (Chalice)      0.008102
# Painter              0.005787
# Other (Delver)       0.005787
# Punishing Dack       0.004630
# Humans               0.004630
# UB Reanimator        0.004630
# Nic Fit              0.004630
# BUG Delver           0.003472
# Goblins              0.003472
# Arclight Phoenix     0.003472
# Tin Fins             0.003472
# Landstill            0.002315
# Esper Mentor         0.001157
# Ruby Storm           0.001157
# Reanimator Depths    0.001157
# Enchantress          0.001157
# Bant Blade           0.001157
# Shardless BUG        0.001157
# Stax                 0.001157
# Aluren               0.001157
# Name: Deck, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.style.use("ggplot")
plt.figure(figsize=(10,7))
plt.plot(range(1,len(preban)+1),preban.cumsum().values, '-s', label='pre-ban')
plt.plot(range(1,len(postban)+1),postban.cumsum().values, '-o', label='post-ban')
plt.legend()
plt.show()

# %%
df['month'] = df['Date'].dt.month
df.groupby(['month', 'Deck'], as_index=False).count()
# Out:
#      month                  Deck  Brainstorm  Chalice  DRS  Date  Placement  \
# 0        1       12 Post Eldrazi           8        8    8     8          8
# 1        1               4c Loam           2        2    2     2          2
# 2        1                   ANT           6        6    6     6          6
# 3        1         BR Reanimator           1        1    1     1          1
# 4        1           BUG Control           1        1    1     1          1
# 5        1            BUG Delver           2        2    2     2          2
# 6        1       Bant Deathblade           2        2    2     2          2
# 7        1               Belcher           2        2    2     2          2
# 8        1                  Burn           4        4    4     4          4
# 9        1            Czech Pile          29       29   29    29         29
# 10       1       Death and Taxes          10       10   10    10         10
# 11       1        Eldrazi Stompy           6        6    6     6          6
# 12       1                 Elves           6        6    6     6          6
# 13       1  Grixis Control (DRS)           1        1    1     1          1
# 14       1         Grixis Delver          19       19   19    19         19
# 15       1                 Lands           3        3    3     3          3
# 16       1             Landstill           2        2    2     2          2
# 17       1           Mana Dredge           5        5    5     5          5
# 18       1              Maverick           2        2    2     2          2
# 19       1               Merfolk           2        2    2     2          2
# 20       1              Miracles          11       11   11    11         11
# 21       1           Moon Stompy           1        1    1     1          1
# 22       1          Other (Blue)           4        4    4     4          4
# 23       1         Other (Rogue)           3        3    3     3          3
# 24       1            RUG Delver           1        1    1     1          1
# 25       1         Shardless BUG           1        1    1     1          1
# 26       1        Sneak and Show          10       10   10    10         10
# 27       1          Steel Stompy           1        1    1     1          1
# 28       1                   TES           4        4    4     4          4
# 29       1          Turbo Depths           5        5    5     5          5
# ..     ...                   ...         ...      ...  ...   ...        ...
# 184      6              Maverick           2        2    2     2          2
# 185      6              Miracles           8        8    8     8          8
# 186      6           Moon Stompy          10       10   10    10         10
# 187      6               Nic Fit           1        1    1     1          1
# 188      6              OmniTell           2        2    2     2          2
# 189      6          Other (Blue)           1        1    1     1          1
# 190      6       Other (Chalice)           1        1    1     1          1
# 191      6        Punishing Dack           3        3    3     3          3
# 192      6        Sneak and Show           5        5    5     5          5
# 193      6                   TES           3        3    3     3          3
# 194      6          Turbo Depths           4        4    4     4          4
# 195      6             UR Delver           1        1    1     1          1
# 196      6        UWx Stoneblade           1        1    1     1          1
# 197      7       12 Post Eldrazi           1        1    1     1          1
# 198      7                   ANT           3        3    3     3          3
# 199      7            BUG Delver           1        1    1     1          1
# 200      7                  Burn           1        1    1     1          1
# 201      7            Czech Pile           7        7    7     7          7
# 202      7        Death's Shadow           1        1    1     1          1
# 203      7           Enchantress           1        1    1     1          1
# 204      7         Grixis Delver           6        6    6     6          6
# 205      7           Mana Dredge           1        1    1     1          1
# 206      7              Miracles           1        1    1     1          1
# 207      7           Moon Stompy           3        3    3     3          3
# 208      7       Other (Chalice)           1        1    1     1          1
# 209      7         Other (Rogue)           1        1    1     1          1
# 210      7        Punishing Dack           1        1    1     1          1
# 211      7            RUG Delver           1        1    1     1          1
# 212      7                   TES           1        1    1     1          1
# 213      7        UWx Stoneblade           1        1    1     1          1
#
#      Player  Top 8
# 0         8      8
# 1         2      2
# 2         6      6
# 3         1      1
# 4         1      1
# 5         2      2
# 6         2      2
# 7         2      2
# 8         4      4
# 9        29     29
# 10       10     10
# 11        6      6
# 12        6      6
# 13        1      1
# 14       19     19
# 15        3      3
# 16        2      2
# 17        5      5
# 18        2      2
# 19        2      2
# 20       11     11
# 21        1      1
# 22        4      4
# 23        3      3
# 24        1      1
# 25        1      1
# 26       10     10
# 27        1      1
# 28        4      4
# 29        5      5
# ..      ...    ...
# 184       2      2
# 185       8      8
# 186      10     10
# 187       1      1
# 188       2      2
# 189       1      1
# 190       1      1
# 191       3      3
# 192       5      5
# 193       3      3
# 194       4      4
# 195       1      1
# 196       1      1
# 197       1      1
# 198       3      3
# 199       1      1
# 200       1      1
# 201       7      7
# 202       1      1
# 203       1      1
# 204       6      6
# 205       1      1
# 206       1      1
# 207       3      3
# 208       1      1
# 209       1      1
# 210       1      1
# 211       1      1
# 212       1      1
# 213       1      1
#
# [214 rows x 9 columns]
